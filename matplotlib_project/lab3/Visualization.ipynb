# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Line Chart

# %% [markdown]
# ### Basic

# %%
x = np.array([1,2,3,4,5,6])
y = np.power(x,2)
plt.plot(x,y)

# %%
x = np.linspace(0, 10, 100) 
y = np.sin(x)
plt.plot(x,y)

# %% [markdown]
# ### Customization

# %%
print(plt.style.available)
plt.style.use('seaborn-v0_8-darkgrid')
plt.figure(figsize=(12,5))
x = np.linspace(0, 10, 100) 
y1 = np.sin(x)
y2 = np.cos(x)
#plt.plot(x,y, 'r-')
plt.plot(x,y1, 'g-', label='$y1=sin(x)$')
plt.plot(x,y2, 'bo', label='$y2=cos(x)$')
plt.xlabel('x')
plt.ylabel('Function Value')
plt.title('$Sin(x) $  $ & $  $ Cos(x)$' ,fontsize = 14)
plt.legend(loc='upper right',bbox_to_anchor=(1.2, 1.0))
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ### Multiplot

# %%
plt.style.use('seaborn-v0_8-darkgrid')
plt.figure(figsize=(12,5))
x = np.linspace(0, 10, 100) 
y1 = np.sin(x)
y2 = np.cos(x)

plt.subplot(2,1,1) # Try 2 rows also
plt.plot(x,y1, 'g-', label='$y1=sin(x)$')
plt.xlabel('x')
plt.ylabel('$sin(x)$')
plt.title('$Sin(x) $' ,fontsize = 14)
plt.legend(loc='upper right')#, bbox_to_anchor=(1.2, 1.0))

plt.subplot(2,1,2)
plt.plot(x,y2, 'bo', label='$y2=cos(x)$')

plt.xlabel('x')
plt.ylabel('$cos(x)$')
plt.title('$Cos(x)$' ,fontsize = 14)
plt.legend(loc='upper right')#, bbox_to_anchor=(1.2, 1.0))

# %% [markdown]
# ### Grid

# %%
x = np.arange(-50,50)
y1 = np.power(x,2)
y2 = np.power(x,3)
y3 = np.sin(x)
y4 = np.cos(x)
y5 = np.tan(x)
y6 = np.tanh(x)
y7 = np.sinh(x)
y8 = np.cosh(x)
y9 = np.exp(x)

fig, ax1 = plt.subplots(nrows=3, ncols=3, figsize=(20,10))
ax1[0,0].plot(x, y1, 'tab:orange')
ax1[0,1].plot(x, y2, 'tab:green')
ax1[0,2].plot(x, y3, 'b-')
ax1[1,0].plot(x, y4, 'r-')
ax1[1,1].plot(x, y5, 'g-')
ax1[1,2].plot(x, y6, 'm-')
ax1[2,0].plot(x, y7, 'y-')
ax1[2,1].plot(x, y8, 'k-')
ax1[2,2].plot(x, y9, 'k-')

# %% [markdown]
# ### Logically driven

# %%
x = [1,2,3,4,5]
y = [[1,2,3,4,5],[10,20,30,40,50],[1,4,9,16,25]]
plt.figure(figsize=(10,6))
for i in y:
      plt.plot(x,i)

# %% [markdown]
# ## Bar Chart

# %% [markdown]
# ### Basic

# %%
id1 = np.arange(1,10)
score = np.arange(20,110,10)
plt.bar(id1,score)
plt.xlabel('Student ID')
plt.ylabel('Score')
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# ### Customization

# %%
id1 = np.arange(1,10)
score = np.arange(20,110,10)
plt.figure(figsize=(8,5))
ax = plt.axes()
ax.set_facecolor("#ECF0FF") 
plt.bar(id1,score,color = '#FFA726', width=0.5)
plt.xlabel(r'$Student   $  $ ID$')
plt.ylabel(r'$Score$')
# Out:
# Text(0, 0.5, '$Score$')

# %% [markdown]
# ### Multiplot

# %%
x1 = [1,3,5,7]
x2 = [2,4,6,8]
y1 = [7,7,7,7]
y2 = [17,18,29,40]
plt.figure(figsize=(8,6))
ax = plt.axes()
ax.set_facecolor("white")
plt.bar(x1,y1,label = "First",color = "#00B386") # First set of data
plt.bar(x2,y2,label = "Second",color = '#94E413', width=0.3) # Second set of data
plt.xlabel('$X$')
plt.ylabel('$Y$')
plt.title ('$Bar $ $ Chart$')
plt.legend()

# %% [markdown]
# ### Horizontal

# %%
Age = [28,33,43,45,57]
Name = ["Asif", "Steve", 'John', "Ravi", "Basit"]
plt.barh(Name,Age, color ="yellowgreen") #horizontal bar chart
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ### Displaying value over bar

# %%
num1 = np.array([1,3,5,7,9])
num2 = np.array([2,4,6,8,10])
plt.figure(figsize=(10,6))
plt.bar(num1, num1**2, width=0.3, color='#FF6F00')
plt.bar(num2, num2**2, width=0.3 , color='#FFB300')
for x,y in zip(num1,num1**2):
      plt.text(x, y-5, '%d' % y, ha='center', va='center')#for the text to be displayed on the bar
for x,y in zip(num2,num2**2):
      plt.text(x, y+0.05, '%d' % y, ha='center', va='center')

# %% [markdown]
# ### Stacked

# %%
plt.style.use('seaborn-darkgrid')
x1 = ['Asif','Basit','Ravi','Minil'] 
y1 = [17,18,29,40]
y2 = [20,21,22,23]
y3 = [5,9,11,12]
plt.figure(figsize=(5,7))
plt.bar(x1, y1, label = "Open Tickets", width = 0.5, color = '#FF6F00')
plt.bar(x1, y2, label = "Closed Tickets", width = 0.5, bottom = y1, color = '#FFB300')
plt.bar(x1, y3, label = "Cancelled Tickets", width = 0.5, bottom = np.add(y1,y2), color = '#F7DC60')
plt.xlabel('$X$')
plt.ylabel('$Y$')
plt.title('$Bar $ $ Chart$')
plt.legend()
#baseline is compromised

# %% [markdown]
# ### Grouped

# %%
# set width of bar
barWidth = 0.25

# set height of bar
y1= np.array([17,18,29,40])
y2 =np.array([20,21,22,23])
y3 =np.array([5,9,11,12])

# Set position of bar on X axis
pos1 = np.arange(len(y1))
pos2 = [x + barWidth for x in pos1]
pos3 = [x + barWidth for x in pos2]

# Make the plot
plt.bar(pos1, y1, color='#FBC02D', width=barWidth, label='Open')
plt.bar(pos2, y2, color='#F57F17', width=barWidth, label='Closed')
plt.bar(pos3, y3, color='#E65100', width=barWidth, label='Cancelled')

# Add xticks on the middle of the group bars
plt.xlabel('Assignee', fontweight='bold')
plt.ylabel('Number of Tickets', fontweight='bold')
plt.xticks([i + barWidth for i in range(len(y1))], ['Asif', 'Basit', 'Ravi', 'Minil'])

plt.legend()
#comparison of data in same category is difficult

# %% [markdown]
# ## Scatter Plot

# %%
plt.style.use('seaborn-darkgrid')

# %% [markdown]
# ### Basic

# %%
x1 = np.array([250,150,350,252,450,550,455,358,158,355])
y1 =np.array([40,50,80, 90, 100,50,60,88,54,45])
x2 = np.array([200,100,300,220,400,500,450,380,180,350])
y2 = np.array([400,500,800, 900, 1000,500,600,808,504,405])
#Graph - 1
plt.scatter(x1,y1, marker='x')
plt.xlabel('$Time $ $ Spent$' , fontsize = 12)
plt.ylabel('$Score$' , fontsize = 12)
plt.title ('Scatter Graph')
plt.show()

# %% [markdown]
# ### Customization

# %%
#Graph - 2
plt.scatter(x2,y2 ,color = 'r')
plt.xlabel('$Time $ $ Spent$' , fontsize = 12)
plt.ylabel('$Score$' , fontsize = 12)
plt.title ('Scatter Graph')
plt.show()

#Graph - 3
plt.scatter(x1,y1 ,label = 'Class 1')
plt.scatter(x2,y2 ,label = 'Class 2',color ='r')
plt.xlabel('$Time $ $ Spent$' , fontsize = 12)
plt.ylabel('$Score$' , fontsize = 12)
plt.title ('Scatter Graph')
plt.legend()
plt.show()

#Graph - 4
plt.scatter(x1,y1 ,label = 'Class 1',marker='o' , color = 'm')
plt.scatter(x2,y2 ,label = 'Class 2',marker='v',color ='r')
plt.xlabel('$Time $ $ Spent$' , fontsize = 12)
plt.ylabel('$Score$' , fontsize = 12)
plt.title ('Scatter Graph')
plt.legend()
plt.show()

# %% [markdown]
# Custom label color

# %%
plt.figure(figsize=(8,6))
x = np.random.random(10)
y = np.random.random(10)
# "alpha" is used for softnening colors
plt.rcParams['text.color'] = 'red' # Label Color
plt.scatter(np.random.random(10),np.random.random(10),c='r', s=50 , alpha=0.3 , label = 'One')
plt.scatter(np.random.random(10),np.random.random(10),c='b', s=100 , alpha=0.6 , label = 'Two')
plt.scatter(np.random.random(10),np.random.random(10),c='g', s=150 , alpha=0.6 , label = 'Three')
plt.scatter(np.random.random(10),np.random.random(10),c='y', s=200 , alpha=0.6 , label = 'Four')
plt.legend(bbox_to_anchor=(1.0, 1.0) , shadow=True, fontsize='x-large')
plt.show()

# %% [markdown]
# ## Pie Chart

# %% [markdown]
# ### Basic

# %%
plt.figure(figsize=(6,6))
tickets = [48 , 30 , 20 , 15]
labels = ['Low' , 'Medium' , 'High' , 'Critical']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']
plt.pie(tickets , labels= labels , colors= colors , startangle=45)
#plt.pie(tickets)
plt.show()

# %% [markdown]
# ### Customization

# %%
plt.figure(figsize=(6,6))
tickets = [48 , 30 , 20 , 15]
labels = ['Low' , 'Medium' , 'High' , 'Critical']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']
explode = [0,0,0,0.2]
plt.pie(tickets , labels= labels , colors= colors , startangle=45, shadow='true', autopct='%2.0f%%', explode=explode)
plt.show()

# %% [markdown]
# ### Multiplot

# %%
fig = plt.figure(figsize=(20,13))
tickets = [48 , 30 , 20 , 15]
priority = ['Low' , 'Medium' , 'High' , 'Critical']
status = ['Resolved' , 'Cancelled' , 'Pending' , 'Assigned']
company = ['IBM' , 'Microsoft', 'BMC' , 'Apple']
colors = ['#8BC34A','#D4E157','#FFB300','#FF7043']

plt.subplot(2,3,1)
plt.pie(tickets, labels=priority, colors=colors, startangle=45, autopct='%1.1f%%')

plt.subplot(2,3,2)
plt.pie(tickets, labels=status, colors=colors, startangle=45, autopct='%1.1f%%')

plt.subplot(2,3,3)
plt.pie(tickets, labels=company, colors=colors, startangle=45, autopct='%1.1f%%')

plt.subplot(2,3,4)
plt.pie(tickets, labels=priority, colors=colors, startangle=45, autopct='%1.1f%%')

plt.subplot(2,3,5)
plt.pie(tickets, labels=status, colors=colors, startangle=45, autopct='%1.1f%%')

plt.subplot(2,3,6)
plt.pie(tickets, labels=company, colors=colors, startangle=45, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %% [markdown]
# ## Line Chart

# %% [markdown]
# ### Basic

# %%
col1 = np.linspace(0, 10, 1000)
col2 = np.sin(col1)
df = pd.DataFrame({"C1" : col1 , "C2" :col2})
df

plt.style.use('seaborn-v0_8-darkgrid')
# %matplotlib inline
sns.lineplot(x=df.C1,y=df.C2,data=df)
# Out:
# <Axes: xlabel='C1', ylabel='C2'>

# %% [markdown]
# ### Customization

# %%
plt.figure(figsize=(14,6))
sns.set(rc={"axes.facecolor":"#FFFDE7", "axes.grid":True,'xtick.labelsize':14,'ytick.labelsize':14})
sns.lineplot(x=df.C1,y=df.C2,data=df,color = "#FF5722", linewidth = 2)
sns.lineplot(x=df.C1,y=df.C2+1,data=df,color = "#FFEB3B", linewidth = 2)
# Out:
# <Axes: xlabel='C1', ylabel='C2'>

# %%
spotify = pd.read_csv('https://raw.githubusercontent.com/dayanandv/Data-Science/main/dataset/spotify.csv', index_col='Date')
spotify.head(4)
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN

# %%
plt.figure(figsize=(20,8))
sns.lineplot(data=spotify)
# Out:
# <Axes: xlabel='Date'>

# %%
spotify.index = pd.to_datetime(spotify.index) # Converting datatype of index to Datetime
plt.figure(figsize=(20,8))
sns.lineplot(data=spotify, linewidth=2)
plt.title("Daily Global Streams")
# Out:
# Text(0.5, 1.0, 'Daily Global Streams')

# %%
employment = pd.read_excel('https://github.com/dayanandv/Data-Science/raw/main/dataset/unemployment.xlsx')
plt.figure(figsize=(18,8))
sns.lineplot(x="Period", y="Unemployed", hue="Gender", data=employment)
plt.title("Employment")
# Out:
# Text(0.5, 1.0, 'Employment')

# %%
employment
# Out:
#                     Age Gender     Period  Unemployed
# 0        16 to 19 years    Men 2005-01-01       91000
# 1        20 to 24 years    Men 2005-01-01      175000
# 2        25 to 34 years    Men 2005-01-01      194000
# 3        35 to 44 years    Men 2005-01-01      201000
# 4        45 to 54 years    Men 2005-01-01      207000
# ...                 ...    ...        ...         ...
# 1703     25 to 34 years  Women 2015-02-01      294000
# 1704     35 to 44 years  Women 2015-02-01      235000
# 1705     45 to 54 years  Women 2015-02-01      253000
# 1706     55 to 64 years  Women 2015-02-01      170000
# 1707  65 years and over  Women 2015-02-01      174000
#
# [1708 rows x 4 columns]

# %% [markdown]
# ## Dist Plot

# %% [markdown]
# Plot a univariate distribution of observations

# %%
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
num = np.random.normal(1,10,1000)
sns.displot(num, kde=True) # Histogram with a kernel density estimate (Density Curve)
plt.show()

# %%
plt.figure(figsize=(23,8))
sns.displot(num,kde=False, rug=True) # Histogram with Rugplot
plt.show()

# %% [markdown]
# Histogram

# %%
housing = pd.read_excel('https://github.com/dayanandv/Data-Science/raw/main/dataset/Housing_data.xlsx')
print(housing.head(3))
housing.hist(bins=40 , figsize=(20,20)) #Pandas Hist function
plt.show()#bins- in each bucket how much value of y axis is there
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
#
#         B  LSTAT  PRICE
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Swarm Plot

# %%
exercise = pd.read_csv('https://raw.githubusercontent.com/dayanandv/Data-Science/main/dataset/exercise.csv')
exercise.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
plt.figure(figsize=(7,7))
sns.swarmplot(x= "kind", y = "pulse", hue="diet", size=9, data = exercise)
plt.show()

# %%
plt.figure(figsize=(11,8))
sns.swarmplot(x=employment.Age,palette="Set1",y = employment.Unemployed)
# Out:
# /var/folders/gk/mxp4gvtj1fg37tq1vbp8d4yc0000gn/T/ipykernel_10850/1633326817.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x=employment.Age,palette="Set1",y = employment.Unemployed)
# /opt/homebrew/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 22.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 9.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 14.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Age', ylabel='Unemployed'>

# %%
sns.set(rc={'xtick.labelsize':10,'ytick.labelsize':10,'axes.labelsize':14})
sns.set_style("white")
sns.catplot(x="Age" , y = "Unemployed" , col= "Gender" , data=employment, kind="swarm",linewidth=2)
plt.show()
# Out:
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 64.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 36.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 23.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 25.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 21.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 41.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 71.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 73.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 51.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 29.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 36.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 30.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 45.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 65.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 68.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 42.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 27.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 24.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 75.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 76.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 55.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 35.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 43.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 38.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 68.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 41.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 27.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 67.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 40.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 44.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 74.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 54.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 33.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 50.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Strip Plot

# %%
plt.figure(figsize=(11,8))
sns.stripplot(x=employment.Unemployed)
plt.show()

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(16,5))
sns.stripplot(x=employment.Age ,palette="Set1", y = employment.Unemployed , jitter=0.3, hue=employment.Gender)

# %% [markdown]
# ## Box Plot

# %%
insurance = pd.read_csv('https://raw.githubusercontent.com/dayanandv/Data-Science/main/dataset/insurance.csv')
insurance.head()
insurance.describe()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=insurance.smoker, y=insurance.charges)#the lines represent the quartiles of the data
#one box is for smokers and the other for non-smokers
plt.show()

# %%
performance = pd.read_csv('https://raw.githubusercontent.com/dayanandv/Data-Science/main/dataset/StudentsPerformance.csv')
performance.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
plt.subplots(figsize = (14,24))
plt.subplot(3,1,1)
sns.boxplot(x=performance['parental level of education'],y=performance['math score'])
plt.subplot(3,1,2)
sns.boxplot(x=performance['parental level of education'],y=performance['reading score'])
plt.subplot(3,1,3)
sns.boxplot(x=performance['parental level of education'],y=performance['writing score'])

# %% [markdown]
# ## Pair Plot

# %%
fish = pd.read_csv('https://github.com/dayanandv/Data-Science/raw/main/dataset/fish.csv')
fish
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
fish1 = fish[fish['Species'].isin(['Bream', 'Perch', 'Pike'])]
fish1.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
plt.figure(figsize=(11,9))
sns.pairplot(fish1,hue = 'Species',palette="autumn" ,height=2)

# %% [markdown]
# ## Heatmap

# %% [markdown]
# A heat map is a data visualization technique that shows magnitude of a phenomenon as color in two dimensions. The variation in color may be by hue or intensity, giving obvious visual cues to the reader about how the phenomenon is clustered or varies over space.

# %%
plt.figure(figsize=(16,9))
canada = pd.read_csv('https://raw.githubusercontent.com/dayanandv/Data-Science/main/dataset/canada.csv')
canada.rename(columns={'OdName':'Country'} , inplace=True)
canada.set_index(canada.Country,inplace=True)
del canada['Country']
canada = canada.transpose()
canada1= canada.loc['2004':, ['Germany' , 'France' , 'Mexico' , 'Bangladesh' ,'Brazil']]
canada1 = canada1.astype(int)
ax = sns.heatmap(canada1,vmin=0, vmax=8000)#, linewidths=0.1, annot=True, fmt="d")
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# ## Joint Plot

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.jointplot(x="bmi", y="charges", data=insurance , height = 10)#, kind="reg"/"resid"/"hex"/"kde")
