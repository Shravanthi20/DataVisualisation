# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Load the Iris dataset
url = 'https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv'
iris = pd.read_csv(url)

fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Sequential colormap
sc1 = axs[0, 0].scatter(iris['sepal_length'], iris['sepal_width'], c=iris['petal_length'], cmap='viridis')#'viridis', 'plasma', 'Blues', 'Reds'
plt.colorbar(sc1, ax=axs[0, 0], label='Petal Length (cm)')
axs[0, 0].set_title('Sequential: Sepal Length vs Sepal Width')
axs[0, 0].set_xlabel('Sepal Length (cm)')
axs[0, 0].set_ylabel('Sepal Width (cm)')

# Diverging colormap
petal_diff = iris['petal_length'] - iris['petal_width']
sc2 = axs[0, 1].scatter(iris['petal_length'], iris['petal_width'], c=petal_diff, cmap='coolwarm')#'coolwarm', 'bwr', 'seismic'
plt.colorbar(sc2, ax=axs[0, 1], label='Petal Length - Petal Width')
axs[0, 1].set_title('Diverging: Petal Length vs Petal Width')
axs[0, 1].set_xlabel('Petal Length (cm)')
axs[0, 1].set_ylabel('Petal Width (cm)')

# Qualitative colormap
species = iris['species'].astype('category').cat.codes
sc3 = axs[1, 0].scatter(iris['sepal_length'], iris['sepal_width'], c=species, cmap='tab10')#tab10', 'Set1', 'Pastel1'
plt.colorbar(sc3, ax=axs[1, 0], ticks=[0,1,2], label='Species')
axs[1, 0].set_title('Qualitative: Sepal Length vs Sepal Width by Species')
axs[1, 0].set_xlabel('Sepal Length (cm)')
axs[1, 0].set_ylabel('Sepal Width (cm)')

# Custom colorbar
sc4 = axs[1, 1].scatter(iris['petal_length'], iris['petal_width'], c=iris['sepal_length'], cmap='plasma')
cb = plt.colorbar(sc4, ax=axs[1, 1], orientation='horizontal', pad=0.2, label='Sepal Length (cm)')
axs[1, 1].set_title('Custom Colorbar Example')
axs[1, 1].set_xlabel('Petal Length (cm)')
axs[1, 1].set_ylabel('Petal Width (cm)')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
df= pd.read_csv('https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv')
fig, axes= plt.subplots(2,2,figsize=(12,10))

sc1= axes[0,0].scatter(iris['sepal_length'],iris['sepal_width'],c=iris['petal_length'],cmap='viridis')
plt.colorbar(sc1,ax=axes[0,0],label='Petal Length')
axes[0,0].set_title('$sepal_length$ vs $sepal_width$')
axes[0,0].set_xlabel('sepal_length')
axes[0,0].set_ylabel('sepal_width')

diff= iris['petal_length']-iris['petal_width']
sc2= axes[0,1].scatter(iris['petal_length'],iris['petal_width'],c=diff,cmap='coolwarm')
plt.colorbar(sc2,ax=axes[0,1],label="petal_length - petal_width")
axes[0,1].set_title('petal length vs petal width')
axes[0,1].set_xlabel('petal_length')
axes[0,1].set_ylabel('petal_width')

species= iris['species'].astype('category').cat.codes
sc3= axes[1,0].scatter(iris['sepal_length'],iris['sepal_width'],c= species,cmap= 'tab10')
cb= plt.colorbar(sc3,ax=axes[1,0],label='Species',orientation='vertical')
cb.set_ticks([0,1,2])
axes[1,0].set_title('sepal length vs sepal width')
axes[1,0].set_xlabel('sepal_length')
axes[1,0].set_ylabel('sepal_width')

sc4= axes[1,1].scatter(iris['petal_length'],iris['petal_width'],c=iris['sepal_length'],cmap='plasma')
plt.colorbar(sc4,ax=axes[1,1],label='Sepal length')
axes[1,1].set_xlabel('Petal_length')
axes[1,1].set_ylabel('Petal Width')
axes[1,1].set_title('petal length vs petal width')

plt.show()
