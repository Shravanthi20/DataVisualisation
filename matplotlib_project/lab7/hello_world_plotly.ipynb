# %% [markdown]
# # Hello World: Plotly and Dash
#
# This short exercise introduces:
#
# - Plotly Express for quick, interactive charts
# - Dash (via JupyterDash) for simple, reactive dashboards right inside a notebook
#
# You'll first see a minimal Plotly chart, then an inline Dash app with a dropdown and a callback.

# %%
# If needed, install dependencies in your environment (uncomment to run once)
# %pip install plotly==5.* jupyter-dash==0.4.* pandas==2.*

import plotly.express as px
import pandas as pd

# Create a tiny DataFrame
animals = pd.DataFrame({
    "animal": ["giraffe", "orangutan", "penguin", "zebra", "lion"],
    "count": [12, 6, 23, 9, 14],
})

# Minimal Plotly Express bar chart
fig = px.bar(animals, x="animal", y="count", title="Hello Plotly: Animal Counts")
fig.update_layout(template="plotly")
fig.show()

# %%
# %pip install jupyter_dash
# Out:
# Collecting jupyter_dash
#   Using cached jupyter_dash-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: dash in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from jupyter_dash) (3.2.0)
# Requirement already satisfied: requests in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from jupyter_dash) (2.32.5)
# Requirement already satisfied: flask in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from jupyter_dash) (3.1.2)
# Requirement already satisfied: retrying in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from jupyter_dash) (1.4.2)
# Requirement already satisfied: ipython in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from jupyter_dash) (9.0.2)
# Requirement already satisfied: ipykernel in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from jupyter_dash) (6.29.5)
# Collecting ansi2html (from jupyter_dash)
#   Using cached ansi2html-1.9.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: nest-asyncio in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from jupyter_dash) (1.6.0)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from dash->jupyter_dash) (3.1.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from dash->jupyter_dash) (6.3.0)
# Requirement already satisfied: importlib-metadata in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from dash->jupyter_dash) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from dash->jupyter_dash) (4.12.2)
# Requirement already satisfied: setuptools in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from dash->jupyter_dash) (65.5.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from flask->jupyter_dash) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from flask->jupyter_dash) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from flask->jupyter_dash) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from flask->jupyter_dash) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from flask->jupyter_dash) (2.1.5)
# Requirement already satisfied: colorama in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from click>=8.1.3->flask->jupyter_dash) (0.4.6)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from plotly>=5.0.0->dash->jupyter_dash) (2.5.0)
# Requirement already satisfied: packaging in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from plotly>=5.0.0->dash->jupyter_dash) (25.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata->dash->jupyter_dash) (3.23.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter_dash) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter_dash) (1.8.13)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter_dash) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter_dash) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter_dash) (0.1.7)
# Requirement already satisfied: psutil in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter_dash) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter_dash) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter_dash) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter_dash) (5.14.3)
# Requirement already satisfied: decorator in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from ipython->jupyter_dash) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from ipython->jupyter_dash) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from ipython->jupyter_dash) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from ipython->jupyter_dash) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from ipython->jupyter_dash) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->jupyter_dash) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter_dash) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter_dash) (309)
# Requirement already satisfied: six>=1.5 in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->jupyter_dash) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from requests->jupyter_dash) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from requests->jupyter_dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from requests->jupyter_dash) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shravanthi s\appdata\local\programs\python\python311\lib\site-packages (from requests->jupyter_dash) (2025.8.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from stack_data->ipython->jupyter_dash) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from stack_data->ipython->jupyter_dash) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\shravanthi s\appdata\roaming\python\python311\site-packages (from stack_data->ipython->jupyter_dash) (0.2.3)
# Using cached jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Using cached ansi2html-1.9.2-py3-none-any.whl (17 kB)
# Installing collected packages: ansi2html, jupyter_dash
#
#    ---------------------------------------- 0/2 [ansi2html]
#    ---------------------------------------- 0/2 [ansi2html]
#    ---------------------------------------- 2/2 [jupyter_dash]
#
# Successfully installed ansi2html-1.9.2 jupyter_dash-0.4.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %%
# Inline Dash app using JupyterDash
from jupyter_dash import JupyterDash
from dash import Dash, dcc, html, Input, Output
import plotly.express as px
import pandas as pd

# Sample dataset
iris = px.data.iris()

# Build the app
app = JupyterDash(__name__)
app.layout = html.Div([
    html.H3("Hello Dash: Iris Scatter"),
    html.Div("Select axes and species to filter."),
    html.Div([
        html.Div([
            html.Label("X-axis"),
            dcc.Dropdown(
                id="x-col",
                options=[{"label": c, "value": c} for c in [
                    "sepal_length", "sepal_width", "petal_length", "petal_width"
                ]],
                value="sepal_length",
                clearable=False,
            ),
        ], style={"flex": 1, "minWidth": 200, "marginRight": 8}),
        html.Div([
            html.Label("Y-axis"),
            dcc.Dropdown(
                id="y-col",
                options=[{"label": c, "value": c} for c in [
                    "sepal_length", "sepal_width", "petal_length", "petal_width"
                ]],
                value="sepal_width",
                clearable=False,
            ),
        ], style={"flex": 1, "minWidth": 200, "marginRight": 8}),
        html.Div([
            html.Label("Species"),
            dcc.Dropdown(
                id="species",
                options=[{"label": s, "value": s} for s in sorted(iris["species"].unique())],
                value=sorted(iris["species"].unique()),
                multi=True,
            ),
        ], style={"flex": 1, "minWidth": 220}),
    ], style={"display": "flex", "flexWrap": "wrap", "marginTop": 8, "marginBottom": 12}),
    dcc.Graph(id="scatter"),
])

# Reactive callback
@app.callback(
    Output("scatter", "figure"),
    Input("x-col", "value"),
    Input("y-col", "value"),
    Input("species", "value"),
)
def update_scatter(x_col, y_col, species_selected):
    df = iris.copy()
    if species_selected:
        df = df[df["species"].isin(species_selected)]
    fig = px.scatter(
        df, x=x_col, y=y_col, color="species",
        title=f"Iris: {x_col} vs {y_col}",
        template="plotly",
        height=420,
    )
    return fig

# Run inline inside notebook
app.run(mode="inline", debug=False)
# Out:
# c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python311\Lib\site-packages\dash\dash.py:634: UserWarning:
#
# JupyterDash is deprecated, use Dash instead.
# See https://dash.plotly.com/dash-in-jupyter for more details.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 71
#      68     return fig
#      70 # Run inline inside notebook
# ---> 71 app.run(mode="inline", debug=False)
#
# File c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python311\Lib\site-packages\dash\dash.py:2363, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_disable_version_check, dev_tools_prune_errors, **flask_run_options)
#    2360             extra_files.append(path)
#    2362 if jupyter_dash.active:
# -> 2363     jupyter_dash.run_app(
#    2364         self,
#    2365         mode=jupyter_mode,
#    2366         width=jupyter_width,
#    2367         height=jupyter_height,
#    2368         host=host,
#    2369         port=port,
#    2370         server_url=jupyter_server_url,
#    2371     )
#    2372 else:
#    2373     self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# File c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python311\Lib\site-packages\dash\_jupyter.py:408, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     406     display(HTML(msg))
#     407 else:
# --> 408     raise final_error
#
# File c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python311\Lib\site-packages\dash\_jupyter.py:395, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     392         raise err
#     394 try:
# --> 395     wait_for_app()
#     397     if self.in_colab:
#     398         JupyterDash._display_in_colab(dashboard_url, port, mode, width, height)
#
# File c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python311\Lib\site-packages\retrying.py:55, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      53 @wraps(f)
#      54 def wrapped_f(*args, **kw):
# ---> 55     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python311\Lib\site-packages\retrying.py:289, in Retrying.call(self, fn, *args, **kwargs)
#     286 if self.stop(attempt_number, delay_since_first_attempt_ms):
#     287     if not self._wrap_exception and attempt.has_exception:
#     288         # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 289         raise attempt.get()
#     290     else:
#     291         raise RetryError(attempt)
#
# File c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python311\Lib\site-packages\retrying.py:326, in Attempt.get(self, wrap_exception)
#     324     else:
#     325         exc_type, exc, tb = self.value
# --> 326         raise exc.with_traceback(tb)
#     327 else:
#     328     return self.value
#
# File c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python311\Lib\site-packages\retrying.py:273, in Retrying.call(self, fn, *args, **kwargs)
#     270     self._before_attempts(attempt_number)
#     272 try:
# --> 273     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     274 except Exception:
#     275     tb = sys.exc_info()
#
# File c:\Users\SHRAVANTHI S\AppData\Local\Programs\Python\Python311\Lib\site-packages\dash\_jupyter.py:386, in JupyterDash.run_app.<locals>.wait_for_app()
#     384     if res != "Alive":
#     385         url = f"http://{host}:{port}"
# --> 386         raise OSError(
#     387             f"Address '{url}' already in use.\n"
#     388             "    Try passing a different port to run."
#     389         )
#     390 except requests.ConnectionError as err:
#     391     _get_error()
#
# OSError: Address 'http://127.0.0.1:8050' already in use.
#     Try passing a different port to run.

# %% [markdown]
# ## Running a Dash app outside the notebook
#
# If you want to run a standalone Dash app from the terminal:
#
# 1. Create a file named `app.py` with the following minimal code:
#
# ```python
# from dash import Dash, dcc, html
# import plotly.express as px
#
# app = Dash(__name__)
# app.layout = html.Div([
#     html.H3("Dash Hello World"),
#     dcc.Graph(figure=px.scatter(px.data.iris(), x="sepal_width", y="sepal_length", color="species"))
# ])
#
# if __name__ == "__main__":
#     app.run(debug=True)
# ```
#
# 2. In your terminal, run:
#
# ```bash
# python app.py
# ```
#
# 3. Open the printed URL (usually `http://127.0.0.1:8050`) in your browser.
#
# Optional: install packages if missing:
#
# ```bash
# pip install plotly==5.* dash==2.* pandas==2.*
# ```

# %%
import pandas as pd
df= pd.read_excel("sales.xls")
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df['Order Date']= pd.to_datetime(df['Order Date'])

# %%
df['Order Date'].dt.year
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2015
# 4       2015
#         ...
# 9989    2014
# 9990    2017
# 9991    2017
# 9992    2017
# 9993    2017
# Name: Order Date, Length: 9994, dtype: int32
